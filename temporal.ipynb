# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
from IPython.display import Image
Image(filename='out/trajectories1-0.png')

# %%
Image(filename='out/trajectories1-1.png')

# %%
Image(filename='out/trajectories1-2.png')

# %%
Image(filename='out/trajectories1-3.png')

# %%
Image(filename='out/trajectories1-4.png')

# %%
Image(filename='out/trajectories1-5.png')

# %%
Image(filename='out/trajectories1-6.png')

# %%
Image(filename='out/trajectories1-7.png')

# %%
Image(filename='out/trajectories1-8.png')

# %%
Image(filename='out/trajectories1-9.png')

# %%
Image(filename='out/trajectories1-10.png')

# %%
Image(filename='out/trajectories1-11.png')

# %%
Image(filename='out/trajectories1-12.png')

# %%
Image(filename='out/trajectories1-13.png')

# %% [markdown]
# ## Trajectory analysis of a random temporal graph

# %%
# %matplotlib inline
from trajectories import *
#k=5
#n=10
#pp=[0.1,0.12,0.08,0.11,0.09]
k=10
n=8
pp=[0.19,.11,.11,.11,.14,.18,.12,.15,.13,.12]
G,ndls,timetoadd=create_synthetic3lg(k,n,pp)
outfile_namestr,outfile_names,outFig_transit,outfile_name_xls,outfile_name_tex= main_work(G,ndls,timetoadd)
k=10
n=8
pp=[0.19,.11,.11,.11,.14,.18,.12,.15,.13,.12]
G,ndls,timetoadd=create_synthetic3lg(k,n,pp)
outfile_namestr,outfile_names,outFig_transit,outfile_name_xls,outfile_name_tex= main_work(G,ndls,timetoadd)
# Out:
# Total number of edges: 31
# Number of edges for the time interval (0, 1): 10
# Number of edges for the time interval (1, 2): 1
# Number of edges for the time interval (2, 3): 1
# Number of edges for the time interval (3, 4): 1
# Number of edges for the time interval (4, 5): 3
# Number of edges for the time interval (5, 6): 3
# Number of edges for the time interval (6, 7): 3
# Number of edges for the time interval (7, 8): 4
# Number of edges for the time interval (8, 9): 2
# Number of edges for the time interval (9, 10): 4
# 57 trajectories analyzed.
# Trajectories of 1: 6
# Trajectories of 0: 11
# Trajectories of 3: 8
# Trajectories of 2: 4
# Trajectories of 5: 8
# Trajectories of 4: 6
# Trajectories of 7: 6
# Trajectories of 6: 8
#
# Average length = 1.56140350877
# Std. dev. of length = 0.8022
#
# +----------+-------------+--------------+-------------+------------+--------------+----------------+-----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |  pOriginator   |   pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+----------------+-----------------+
# |    1     |      6      |      0       |      2      |     2      |      6       |      1.0       |       0.0       |
# |    0     |      6      |      1       |      11     |     6      |      12      |      0.5       | 0.0833333333333 |
# |    3     |      14     |      0       |      5      |     5      |      14      |      1.0       |       0.0       |
# |    2     |      5      |      4       |      1      |     1      |      9       | 0.555555555556 |  0.444444444444 |
# |    5     |      6      |      2       |      11     |     5      |      14      | 0.428571428571 |  0.142857142857 |
# |    4     |      6      |      3       |      9      |     6      |      12      |      0.5       |       0.25      |
# |    7     |      6      |      0       |      5      |     4      |      7       | 0.857142857143 |       0.0       |
# |    6     |      8      |      0       |      13     |     8      |      13      | 0.615384615385 |       0.0       |
# +----------+-------------+--------------+-------------+------------+--------------+----------------+-----------------+
#
#
#
# +----------+----------------+----------------+---------------+---------------+---------------+------------+
# | Vertices |  pTerminator   |   pBlackHole   |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+----------------+----------------+---------------+---------------+---------------+------------+
# |    1     | 0.333333333333 | 0.333333333333 | 2.16666666667 |       0       |      2.0      |    1.0     |
# |    0     | 0.916666666667 |      0.5       |      1.0      |      3.0      | 1.45454545455 |    1.0     |
# |    3     | 0.357142857143 | 0.357142857143 | 2.07142857143 |       0       |      1.0      |    1.0     |
# |    2     | 0.111111111111 | 0.111111111111 |      1.8      |      3.0      |      1.0      |    1.0     |
# |    5     | 0.785714285714 | 0.357142857143 | 1.33333333333 |      3.5      | 1.63636363636 |    1.0     |
# |    4     |      0.75      |      0.5       | 1.33333333333 | 3.33333333333 | 1.88888888889 |    1.0     |
# |    7     | 0.714285714286 | 0.571428571429 | 1.33333333333 |       0       |      1.2      |    1.0     |
# |    6     |      1.0       | 0.615384615385 |      1.0      |       0       | 1.69230769231 |    1.0     |
# +----------+----------------+----------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |    1     | 2.16666666667 | 1.28571428571 | 14.2857142857 |      0      |
# |    0     | 1.58333333333 |      1.5      | 45.8333333333 |      1      |
# |    3     | 2.07142857143 |      1.0      |      0.0      |      0      |
# |    2     | 2.33333333333 | 1.44444444444 | 22.2222222222 |      4      |
# |    5     |      2.0      | 1.71428571429 | 51.1904761905 |      3      |
# |    4     |      2.25     | 1.84615384615 | 41.0256410256 |      4      |
# |    7     | 1.42857142857 | 1.14285714286 | 14.2857142857 |      0      |
# |    6     | 1.69230769231 | 1.69230769231 | 38.4615384615 |      0      |
# +----------+---------------+---------------+---------------+-------------+
# Total number of edges: 33
# Number of edges for the time interval (0, 1): 3
# Number of edges for the time interval (1, 2): 9
# Number of edges for the time interval (2, 3): 1
# Number of edges for the time interval (3, 4): 3
# Number of edges for the time interval (4, 5): 6
# Number of edges for the time interval (5, 6): 3
# Number of edges for the time interval (6, 7): 5
# Number of edges for the time interval (7, 8): 6
# Number of edges for the time interval (8, 9): 2
# 69 trajectories analyzed.
# Trajectories of 1: 6
# Trajectories of 0: 19
# Trajectories of 3: 9
# Trajectories of 2: 6
# Trajectories of 5: 3
# Trajectories of 4: 11
# Trajectories of 7: 5
# Trajectories of 6: 10
#
# Average length = 3.59420289855
# Std. dev. of length = 1.9199
#
# +----------+-------------+--------------+-------------+------------+--------------+----------------+----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |  pOriginator   |  pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+----------------+----------------+
# |    1     |      0      |      6       |      18     |     0      |      22      |      0.0       | 0.272727272727 |
# |    0     |      7      |      15      |      7      |     3      |      24      | 0.291666666667 |     0.625      |
# |    3     |      4      |      12      |      17     |     2      |      31      | 0.129032258065 | 0.387096774194 |
# |    2     |      15     |      21      |      3      |     1      |      38      | 0.394736842105 | 0.552631578947 |
# |    5     |      15     |      0       |      1      |     0      |      16      |     0.9375     |      0.0       |
# |    4     |      14     |      24      |      6      |     2      |      29      | 0.48275862069  | 0.827586206897 |
# |    7     |      4      |      22      |      11     |     2      |      29      | 0.137931034483 | 0.758620689655 |
# |    6     |      10     |      20      |      6      |     2      |      28      | 0.357142857143 | 0.714285714286 |
# +----------+-------------+--------------+-------------+------------+--------------+----------------+----------------+
#
#
#
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator   |    pBlackHole   |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# |    1     |  0.818181818182 |       0.0       |       0       |      7.5      | 4.05555555556 |     0      |
# |    0     |  0.291666666667 |      0.125      | 2.71428571429 | 5.46666666667 | 2.71428571429 |    1.0     |
# |    3     |  0.548387096774 | 0.0645161290323 |      1.5      | 5.16666666667 | 4.11764705882 |    1.0     |
# |    2     | 0.0789473684211 | 0.0263157894737 | 2.86666666667 | 4.61904761905 |      2.0      |    1.0     |
# |    5     |      0.0625     |       0.0       |      4.6      |       0       |      2.0      |     0      |
# |    4     |  0.206896551724 | 0.0689655172414 | 3.78571428571 | 6.45833333333 |      3.0      |    1.0     |
# |    7     |  0.379310344828 | 0.0689655172414 |      1.5      | 4.77272727273 | 4.54545454545 |    1.0     |
# |    6     |  0.214285714286 | 0.0714285714286 |      5.2      |      5.5      | 1.66666666667 |    1.0     |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |    1     | 4.68181818182 | 4.16666666667 | 88.3928571429 |      84     |
# |    0     |     4.375     | 2.07142857143 | 36.9897959184 |      68     |
# |    3     | 4.38709677419 | 3.93548387097 | 77.5268817204 |      38     |
# |    2     | 3.81578947368 | 1.78947368421 | 26.6666666667 |      57     |
# |    5     |     4.4375    |     1.0625    |      6.25     |      0      |
# |    4     | 4.72413793103 | 2.90476190476 | 39.1723356009 |     129     |
# |    7     | 4.41379310345 |      3.2      | 55.0476190476 |     102     |
# |    6     | 4.46428571429 | 2.82352941176 | 48.6554621849 |      47     |
# +----------+---------------+---------------+---------------+-------------+

# %% [markdown]
# ## Trajectory analysis of a random temporal bipartite graph

# %%
k=10
n=8
m=8
pp=[0.08,.082,.081,.081,.074,.081,.072,.075,.083,.08]
G,ndls,timetoadd=create_synthetic3lgB(k,n,m,pp) 
main_work(G,ndls,timetoadd)
# Out:
# Total number of edges: 92
# Number of edges in time interval (0, 1): 8
# Number of edges in time interval (1, 2): 9
# Number of edges in time interval (2, 3): 11
# Number of edges in time interval (3, 4): 13
# Number of edges in time interval (4, 5): 12
# Number of edges in time interval (5, 6): 9
# Number of edges in time interval (6, 7): 12
# Number of edges in time interval (7, 8): 10
# Number of edges in time interval (8, 9): 12
# Number of edges in time interval (9, 10): 12
# 415 trajectories analyzed.
# Trajectories of B14: 12
# Trajectories of B15: 80
# Trajectories of B12: 47
# Trajectories of B13: 49
# Trajectories of B10: 8
# Trajectories of B11: 9
# Trajectories of B8: 9
# Trajectories of B9: 201
#
# Average length = 5.56144578313
# Std. dev. of length = 2.0205
#
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |   pOriginator   |  pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# |    A1    |      7      |      46      |      71     |     4      |     115      | 0.0608695652174 |      0.4       |
# |    A0    |     118     |     245      |      51     |     2      |     328      |  0.359756097561 | 0.746951219512 |
# |    A3    |      59     |     156      |      4      |     1      |     203      |  0.290640394089 | 0.768472906404 |
# |    A2    |      53     |     274      |      11     |     0      |     263      |  0.201520912548 | 1.04182509506  |
# |    A5    |     106     |     179      |      26     |     23     |     254      |  0.417322834646 | 0.704724409449 |
# |    A4    |      60     |     126      |     204     |     57     |     250      |       0.24      |     0.504      |
# |    A7    |      7      |     226      |      3      |     1      |     156      | 0.0448717948718 | 1.44871794872  |
# |    A6    |      5      |     235      |      45     |     2      |     259      |  0.019305019305 | 0.907335907336 |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
#
#
#
# +----------+-----------------+------------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator   |    pBlackHole    |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+-----------------+------------------+---------------+---------------+---------------+------------+
# |    A1    |  0.617391304348 | 0.0347826086957  |      3.0      |  6.4347826087 | 6.14084507042 |    2.0     |
# |    A0    |  0.155487804878 | 0.00609756097561 | 6.69491525424 | 5.55102040816 | 7.21568627451 |    2.0     |
# |    A3    | 0.0197044334975 | 0.00492610837438 |  5.1186440678 |  7.4358974359 |      1.75     |    2.0     |
# |    A2    |  0.041825095057 |       0.0        | 7.11320754717 | 6.81386861314 | 3.18181818182 |     0      |
# |    A5    |  0.102362204724 | 0.0905511811024  | 4.60377358491 | 6.69832402235 | 3.88461538462 |    2.0     |
# |    A4    |      0.816      |      0.228       |      4.95     | 6.50793650794 |  5.0637254902 |    2.0     |
# |    A7    | 0.0192307692308 | 0.00641025641026 | 2.71428571429 |  7.6814159292 | 1.66666666667 |    2.0     |
# |    A6    |  0.173745173745 | 0.00772200772201 |      2.8      | 6.30212765957 | 7.17777777778 |    2.0     |
# +----------+-----------------+------------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |    A1    | 6.24347826087 | 5.05691056911 | 75.3135888502 |     370     |
# |    A0    |  6.1493902439 |      3.25     | 44.2920711974 |     803     |
# |    A3    | 6.70935960591 | 2.74770642202 | 28.8597640891 |     1314    |
# |    A2    | 6.33840304183 | 3.21893491124 |  39.442565981 |     2036    |
# |    A5    | 5.81496062992 | 3.04180064309 |  40.266166488 |     1310    |
# |    A4    |     5.364     | 4.08762886598 | 69.2274177712 |     1061    |
# |    A7    | 7.04487179487 | 4.33617021277 | 51.4657210402 |     1420    |
# |    A6    |  6.2277992278 |  4.3038869258 | 57.7301026418 |     1954    |
# +----------+---------------+---------------+---------------+-------------+
# 219 trajectories analyzed.
# Trajectories of A1: 8
# Trajectories of A0: 3
# Trajectories of A3: 8
# Trajectories of A2: 36
# Trajectories of A5: 150
# Trajectories of A4: 4
# Trajectories of A7: 4
# Trajectories of A6: 6
#
# Average length = 9.32420091324
# Std. dev. of length = 1.0751
#
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |   pOriginator   |  pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# |   B14    |      10     |     211      |      4      |     0      |     157      | 0.0636942675159 | 1.34394904459  |
# |   B15    |      3      |     202      |      5      |     1      |     185      | 0.0162162162162 | 1.09189189189  |
# |   B12    |     150     |     223      |     154     |    150     |     213      |  0.704225352113 | 1.04694835681  |
# |   B13    |      36     |     211      |      1      |     0      |     199      |  0.180904522613 | 1.06030150754  |
# |   B10    |      0      |     141      |      43     |     0      |     129      |       0.0       | 1.09302325581  |
# |   B11    |      4      |     202      |      0      |     0      |     157      | 0.0254777070064 | 1.28662420382  |
# |    B8    |      16     |     124      |      3      |     0      |     129      |  0.124031007752 | 0.961240310078 |
# |    B9    |      0      |     290      |      9      |     0      |     191      |       0.0       | 1.51832460733  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
#
#
#
# +----------+------------------+------------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator    |    pBlackHole    |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+------------------+------------------+---------------+---------------+---------------+------------+
# |   B14    | 0.0254777070064  |       0.0        |      9.1      |  9.5971563981 |      9.0      |     0      |
# |   B15    |  0.027027027027  | 0.00540540540541 |      9.0      | 9.21782178218 |      9.0      |    3.0     |
# |   B12    |  0.723004694836  |  0.704225352113  | 9.66666666667 | 9.28251121076 | 9.64935064935 |    3.0     |
# |   B13    | 0.00502512562814 |       0.0        | 8.16666666667 | 9.62085308057 |      9.0      |     0      |
# |   B10    |  0.333333333333  |       0.0        |       0       | 9.04964539007 | 8.37209302326 |     0      |
# |   B11    |       0.0        |       0.0        |      9.0      | 9.68811881188 |       0       |     0      |
# |    B8    | 0.0232558139535  |       0.0        |      9.0      | 9.70161290323 | 8.33333333333 |     0      |
# |    B9    | 0.0471204188482  |       0.0        |       0       | 9.60344827586 |      9.0      |     0      |
# +----------+------------------+------------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |   B14    | 9.54777070064 | 4.41777777778 | 40.1832772166 |     2728    |
# |   B15    | 9.27567567568 | 5.33333333333 | 52.9214251357 |     3212    |
# |   B12    | 9.34272300469 | 6.09487666034 |  59.952506907 |     732     |
# |   B13    | 9.30653266332 | 4.08870967742 | 35.7169331564 |     3215    |
# |   B10    | 9.18604651163 | 6.54347826087 | 68.7695863919 |     1292    |
# |   B11    |  9.5923566879 | 6.31553398058 | 61.2967399375 |     3439    |
# |    B8    |  9.6511627907 | 5.90909090909 | 57.0991634628 |     1999    |
# |    B9    | 9.44502617801 | 3.26755852843 | 26.9116390856 |     2337    |
# +----------+---------------+---------------+---------------+-------------+
