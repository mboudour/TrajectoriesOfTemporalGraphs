# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
from IPython.display import Image
Image(filename='out/trajectories1-0.png')

# %%
Image(filename='out/trajectories1-1.png')

# %% [markdown]
# # The Python scripts for all the computations displayed here are available at:

# %% [markdown]
# # [https://github.com/mboudour/TrajectoriesOfTemporalGraphs](https://github.com/mboudour/TrajectoriesOfTemporalGraphs)

# %%
Image(filename='out/trajectories1-2.png')

# %%
Image(filename='out/trajectories1-3.png')

# %%
Image(filename='out/trajectories1-4.png')

# %%
Image(filename='out/trajectories1-5.png')

# %%
Image(filename='out/trajectories1-6.png')

# %%
Image(filename='out/trajectories1-7.png')

# %%
Image(filename='out/trajectories1-8.png')

# %%
Image(filename='out/trajectories1-9.png')

# %%
Image(filename='out/trajectories1-10.png')

# %%
Image(filename='out/trajectories1-11.png')

# %%
Image(filename='out/trajectories1-12.png')

# %%
Image(filename='out/trajectories1-13.png')

# %% [markdown]
# ## Trajectory analysis of a random temporal graph

# %%
# %matplotlib inline
from trajectories import *
#k=5
#n=10
#pp=[0.1,0.12,0.08,0.11,0.09]
k=10
n=8
pp=[0.19,.11,.11,.11,.14,.18,.12,.15,.13,.12]
G,ndls,timetoadd=create_synthetic3lg(k,n,pp)
outfile_namestr,outfile_names,outFig_transit,outfile_name_xls,outfile_name_tex= main_work(G,ndls,timetoadd)
k=10
n=8
pp=[0.19,.11,.11,.11,.14,.18,.12,.15,.13,.12]
G,ndls,timetoadd=create_synthetic3lg(k,n,pp)
outfile_namestr,outfile_names,outFig_transit,outfile_name_xls,outfile_name_tex= main_work(G,ndls,timetoadd)
# Out:
# Total number of edges: 28
# Number of edges for the time interval (0, 1): 3
# Number of edges for the time interval (1, 2): 3
# Number of edges for the time interval (2, 3): 4
# Number of edges for the time interval (3, 4): 2
# Number of edges for the time interval (4, 5): 3
# Number of edges for the time interval (5, 6): 6
# Number of edges for the time interval (6, 7): 3
# Number of edges for the time interval (7, 8): 6
# Number of edges for the time interval (8, 9): 1
# Number of edges for the time interval (9, 10): 2
# 140 trajectories analyzed.
# Trajectories of 1: 5
# Trajectories of 0: 106
# Trajectories of 3: 4
# Trajectories of 2: 6
# Trajectories of 5: 4
# Trajectories of 4: 2
# Trajectories of 7: 6
# Trajectories of 6: 7
#
# Average length = 6.47857142857
# Std. dev. of length = 2.7575
#
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+-----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |   pOriginator   |   pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+-----------------+
# |    1     |      3      |      85      |      5      |     3      |      75      |       0.04      |  1.13333333333  |
# |    0     |      18     |      2       |      7      |     5      |      22      |  0.818181818182 | 0.0909090909091 |
# |    3     |      2      |      3       |      3      |     2      |      6       |  0.333333333333 |       0.5       |
# |    2     |      3      |     121      |      2      |     2      |      94      |  0.031914893617 |  1.28723404255  |
# |    5     |      3      |      45      |      1      |     0      |      48      |      0.0625     |      0.9375     |
# |    4     |     104     |     172      |     104     |    104     |     109      |  0.954128440367 |  1.57798165138  |
# |    7     |      3      |     147      |      9      |     2      |     114      | 0.0263157894737 |  1.28947368421  |
# |    6     |      4      |      67      |      9      |     2      |      78      | 0.0512820512821 |  0.858974358974 |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+-----------------+
#
#
#
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator   |    pBlackHole   |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# |    1     | 0.0666666666667 |       0.04      |      1.0      | 7.96470588235 |      1.4      |    1.0     |
# |    0     |  0.318181818182 |  0.227272727273 |      3.0      |      4.5      | 1.57142857143 |    1.0     |
# |    3     |       0.5       |  0.333333333333 |      1.0      | 4.33333333333 | 1.66666666667 |    1.0     |
# |    2     | 0.0212765957447 | 0.0212765957447 | 1.33333333333 | 7.97520661157 |      1.0      |    1.0     |
# |    5     | 0.0208333333333 |       0.0       | 4.33333333333 | 7.93333333333 |      3.0      |     0      |
# |    4     |  0.954128440367 |  0.954128440367 | 7.89423076923 | 8.18604651163 | 7.89423076923 |    1.0     |
# |    7     | 0.0789473684211 | 0.0175438596491 | 1.33333333333 | 7.94557823129 | 3.55555555556 |    1.0     |
# |    6     |  0.115384615385 |  0.025641025641 |      1.5      | 8.01492537313 | 2.88888888889 |    1.0     |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |    1     | 7.41333333333 | 4.34444444444 | 49.7028218695 |     879     |
# |    0     | 3.04545454545 | 1.26086956522 | 15.5797101449 |      5      |
# |    3     |      3.0      |      2.0      | 36.1111111111 |      8      |
# |    2     | 7.63829787234 | 4.06451612903 | 44.0469790067 |     963     |
# |    5     | 7.66666666667 | 2.04081632653 | 18.1519274376 |     267     |
# |    4     | 7.71559633028 | 4.36315789474 | 48.0925229741 |      10     |
# |    7     |      7.5      | 5.63057324841 | 68.7089273077 |     1278    |
# |    6     | 7.26923076923 | 4.38461538462 | 53.0514855515 |     835     |
# +----------+---------------+---------------+---------------+-------------+
# Total number of edges: 34
# Number of edges for the time interval (0, 1): 3
# Number of edges for the time interval (1, 2): 1
# Number of edges for the time interval (2, 3): 3
# Number of edges for the time interval (3, 4): 4
# Number of edges for the time interval (4, 5): 7
# Number of edges for the time interval (5, 6): 4
# Number of edges for the time interval (6, 7): 2
# Number of edges for the time interval (7, 8): 7
# Number of edges for the time interval (8, 9): 2
# Number of edges for the time interval (9, 10): 7
# 69 trajectories analyzed.
# Trajectories of 1: 6
# Trajectories of 0: 13
# Trajectories of 3: 7
# Trajectories of 2: 4
# Trajectories of 5: 19
# Trajectories of 4: 5
# Trajectories of 7: 5
# Trajectories of 6: 10
#
# Average length = 3.3768115942
# Std. dev. of length = 1.8558
#
# +----------+-------------+--------------+-------------+------------+--------------+----------------+-----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |  pOriginator   |   pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+----------------+-----------------+
# |    1     |      8      |      14      |      16     |     4      |      25      |      0.32      |       0.56      |
# |    0     |      8      |      12      |      13     |     4      |      27      | 0.296296296296 |  0.444444444444 |
# |    3     |      3      |      14      |      4      |     3      |      18      | 0.166666666667 |  0.777777777778 |
# |    2     |      7      |      1       |      8      |     2      |      14      |      0.5       | 0.0714285714286 |
# |    5     |      8      |      19      |      10     |     5      |      29      | 0.275862068966 |  0.655172413793 |
# |    4     |      10     |      14      |      3      |     2      |      21      | 0.47619047619  |  0.666666666667 |
# |    7     |      11     |      27      |      1      |     1      |      26      | 0.423076923077 |  1.03846153846  |
# |    6     |      14     |      15      |      14     |     6      |      31      | 0.451612903226 |  0.483870967742 |
# +----------+-------------+--------------+-------------+------------+--------------+----------------+-----------------+
#
#
#
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator   |    pBlackHole   |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# |    1     |       0.64      |       0.16      |     4.125     | 5.14285714286 |     4.5625    |    1.0     |
# |    0     |  0.481481481481 |  0.148148148148 |     2.125     | 4.83333333333 | 3.30769230769 |    1.0     |
# |    3     |  0.222222222222 |  0.166666666667 |      1.0      | 4.78571428571 |      1.5      |    1.0     |
# |    2     |  0.571428571429 |  0.142857142857 | 3.28571428571 |      3.0      |     4.375     |    1.0     |
# |    5     |  0.344827586207 |  0.172413793103 |     2.625     |      5.0      |      2.0      |    1.0     |
# |    4     |  0.142857142857 | 0.0952380952381 |      4.2      | 5.14285714286 | 1.66666666667 |    1.0     |
# |    7     | 0.0384615384615 | 0.0384615384615 | 4.36363636364 | 5.14814814815 |      3.0      |    1.0     |
# |    6     |  0.451612903226 |  0.193548387097 | 3.28571428571 | 4.66666666667 | 3.42857142857 |    1.0     |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |    1     |      4.6      | 3.26315789474 | 60.5263157895 |      44     |
# |    0     | 3.77777777778 | 2.51724137931 | 44.1379310345 |      50     |
# |    3     | 4.05555555556 | 2.66666666667 | 46.3888888889 |      50     |
# |    2     | 4.21428571429 |      3.0      | 46.4285714286 |      1      |
# |    5     | 3.96551724138 |    2.53125    | 45.2604166667 |      56     |
# |    4     | 4.61904761905 |      2.28     | 33.2666666667 |      43     |
# |    7     | 4.73076923077 | 2.76923076923 | 44.5299145299 |      61     |
# |    6     | 4.03225806452 | 2.47368421053 | 39.9561403509 |      46     |
# +----------+---------------+---------------+---------------+-------------+

# %% [markdown]
# ## Trajectory analysis of a random temporal bipartite graph

# %%
k=10
n=8
m=8
pp=[0.08,.082,.081,.081,.074,.081,.072,.075,.083,.08]
G,ndls,timetoadd=create_synthetic3lgB(k,n,m,pp) 
main_work(G,ndls,timetoadd)
# Out:
# Total number of edges: 90
# Number of edges in time interval (0, 1): 10
# Number of edges in time interval (1, 2): 14
# Number of edges in time interval (2, 3): 11
# Number of edges in time interval (3, 4): 11
# Number of edges in time interval (4, 5): 11
# Number of edges in time interval (5, 6): 10
# Number of edges in time interval (6, 7): 9
# Number of edges in time interval (7, 8): 12
# Number of edges in time interval (8, 9): 9
# Number of edges in time interval (9, 10): 12
# 837 trajectories analyzed.
# Trajectories of B14: 432
# Trajectories of B15: 10
# Trajectories of B12: 11
# Trajectories of B13: 3
# Trajectories of B10: 270
# Trajectories of B11: 94
# Trajectories of B8: 11
# Trajectories of B9: 6
#
# Average length = 7.41696535245
# Std. dev. of length = 2.3507
#
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |   pOriginator   |  pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# |    A1    |      64     |     442      |      11     |     2      |     482      |  0.132780082988 | 0.917012448133 |
# |    A0    |      92     |     951      |     128     |     57     |     750      |  0.122666666667 |     1.268      |
# |    A3    |      42     |     498      |     176     |     1      |     616      | 0.0681818181818 | 0.808441558442 |
# |    A2    |      4      |     143      |      38     |     4      |     172      | 0.0232558139535 | 0.831395348837 |
# |    A5    |      62     |     288      |      73     |     18     |     401      |  0.154613466334 | 0.718204488778 |
# |    A4    |      10     |     931      |     270     |     0      |     747      | 0.0133868808568 | 1.24631860776  |
# |    A7    |     503     |     759      |     109     |     19     |     632      |  0.795886075949 | 1.20094936709  |
# |    A6    |      60     |     535      |      32     |     8      |     497      |  0.120724346076 | 1.07645875252  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
#
#
#
# +----------+-----------------+------------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator   |    pBlackHole    |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+-----------------+------------------+---------------+---------------+---------------+------------+
# |    A1    | 0.0228215767635 | 0.00414937759336 |      5.5      | 7.56108597285 | 3.18181818182 |    2.0     |
# |    A0    |  0.170666666667 |      0.076       | 5.14130434783 | 8.54574132492 |   5.6953125   |    2.0     |
# |    A3    |  0.285714285714 | 0.00162337662338 | 4.92857142857 | 8.26506024096 | 8.64772727273 |    2.0     |
# |    A2    |  0.220930232558 | 0.0232558139535  |      1.5      |  5.7972027972 | 4.47368421053 |    2.0     |
# |    A5    |  0.182044887781 | 0.0448877805486  | 5.56451612903 | 8.36458333333 | 5.76712328767 |    2.0     |
# |    A4    |  0.361445783133 |       0.0        |      4.6      | 8.30934479055 | 9.54074074074 |     0      |
# |    A7    |  0.17246835443  | 0.0300632911392  | 8.81908548708 | 9.29512516469 | 5.50458715596 |    2.0     |
# |    A6    | 0.0643863179074 | 0.0160965794769  | 5.71666666667 | 8.68598130841 |    4.84375    |    2.0     |
# +----------+-----------------+------------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |    A1    | 7.30705394191 | 3.18640776699 | 38.5636251559 |     3725    |
# |    A0    | 7.59466666667 | 3.96749358426 | 42.5794545726 |     9527    |
# |    A3    | 7.92857142857 | 6.21818181818 | 66.3291052382 |     5524    |
# |    A2    | 5.51162790698 | 4.32417582418 | 72.5183150183 |     560     |
# |    A5    | 7.62842892768 | 2.74761904762 | 32.2999209785 |     1931    |
# |    A4    | 7.79384203481 | 5.71593724195 | 61.0396104492 |    16616    |
# |    A7    | 8.15189873418 | 4.41605839416 | 44.8701246037 |     145     |
# |    A6    | 8.07645875252 |  4.4696485623 | 48.7758806689 |     5990    |
# +----------+---------------+---------------+---------------+-------------+
# 116 trajectories analyzed.
# Trajectories of A1: 32
# Trajectories of A0: 24
# Trajectories of A3: 20
# Trajectories of A2: 4
# Trajectories of A5: 10
# Trajectories of A4: 6
# Trajectories of A7: 16
# Trajectories of A6: 4
#
# Average length = 9.03448275862
# Std. dev. of length = 1.0708
#
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# | Vertices | fOriginator | fTransmitter | fTerminator | fBlackHole | fInvolvement |   pOriginator   |  pTransmitter  |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
# |   B14    |      8      |     126      |      10     |     0      |      88      | 0.0909090909091 | 1.43181818182  |
# |   B15    |      0      |      75      |      14     |     0      |      71      |       0.0       | 1.05633802817  |
# |   B12    |      4      |     110      |      4      |     4      |      94      | 0.0425531914894 | 1.17021276596  |
# |   B13    |      0      |      88      |      0      |     0      |      67      |       0.0       | 1.31343283582  |
# |   B10    |      58     |     121      |      58     |     16     |     114      |  0.508771929825 | 1.06140350877  |
# |   B11    |      24     |     130      |      12     |     0      |     108      |  0.222222222222 |  1.2037037037  |
# |    B8    |      6      |     124      |      0      |     0      |      84      | 0.0714285714286 | 1.47619047619  |
# |    B9    |      16     |      42      |      18     |     0      |      68      |  0.235294117647 | 0.617647058824 |
# +----------+-------------+--------------+-------------+------------+--------------+-----------------+----------------+
#
#
#
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# | Vertices |   pTerminator   |    pBlackHole   |  lOriginator  |  lTransmitter |  lTerminator  | lBlackHole |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
# |   B14    |  0.113636363636 |       0.0       |      9.0      | 8.89682539683 |      7.7      |     0      |
# |   B15    |  0.197183098592 |       0.0       |       0       | 9.50666666667 |      8.5      |     0      |
# |   B12    | 0.0425531914894 | 0.0425531914894 |      9.0      | 9.06363636364 |      9.0      |    3.0     |
# |   B13    |       0.0       |       0.0       |       0       |      9.5      |       0       |     0      |
# |   B10    |  0.508771929825 |  0.140350877193 | 8.98275862069 |  9.1652892562 | 9.43103448276 |    3.0     |
# |   B11    |  0.111111111111 |       0.0       | 8.66666666667 | 8.99230769231 |      9.0      |     0      |
# |    B8    |       0.0       |       0.0       | 8.16666666667 | 9.40322580645 |       0       |     0      |
# |    B9    |  0.264705882353 |       0.0       |     10.125    | 9.35714285714 | 8.94444444444 |     0      |
# +----------+-----------------+-----------------+---------------+---------------+---------------+------------+
#
#
#
# +----------+---------------+---------------+---------------+-------------+
# | Vertices |  lInvolvement |    Position   |  RelPosition  | Betweenness |
# +----------+---------------+---------------+---------------+-------------+
# |   B14    | 8.84090909091 |     5.4375    | 57.9905202822 |     1403    |
# |   B15    | 9.28169014085 | 5.31460674157 | 51.7888353843 |     1084    |
# |   B12    | 9.07446808511 |      4.5      | 44.0469464622 |     1522    |
# |   B13    | 9.23880597015 | 5.39772727273 |  52.968975469 |     861     |
# |   B10    | 9.04385964912 | 5.08860759494 | 49.1397093296 |     1665    |
# |   B11    | 8.96296296296 | 4.30722891566 | 41.9415758271 |     1412    |
# |    B8    | 9.16666666667 | 5.20769230769 | 48.3611111111 |     1832    |
# |    B9    | 9.33823529412 | 6.10526315789 | 61.6577903091 |     373     |
# +----------+---------------+---------------+---------------+-------------+
